# %%
import numpy as np
M = np.load(r'C:\Users\mayib\Desktop\Figure\data\Misalignment_Factor_Province.npy', allow_pickle=True).item()
M_std = np.load(r'C:\Users\mayib\Desktop\Figure\data\Misalignment_Factor_Province_std.npy', allow_pickle=True).item()

# %%
M.keys(), M['Without Method']['Beijing']
# Out:
# (dict_keys(['Without Method', 'Threshold-based Method', 'Greedy', 'DeepEnergy']),
#  [0.5391345308665842,
#   0.5343259735463441,
#   0.5302902209319921,
#   0.5278331060216642,
#   0.5259530941804155,
#   0.5251361573546744,
#   0.5248368183572993,
#   0.5243940417665452,
#   0.5236826843109539,
#   0.524346379066406,
#   0.5229664667380618,
#   0.5216039382353729,
#   0.5227092284795825,
#   0.5233566528298808,
#   0.5232104975127485,
#   0.5221101857575681,
#   0.5207175930199094])

# %%
for p in M['Without Method']:
    line = p
    for i, m in enumerate(M['Without Method'][p]):
        line += ' & ' + str(round(m, 4)) + '$\pm$' + str(round(M_std['Without Method'][p][i], 4))
    line += r' \\'
    print(line)
    print('\hline')
# Out:
# Beijing & 0.5391$\pm$0.0031 & 0.5343$\pm$0.0031 & 0.5303$\pm$0.003 & 0.5278$\pm$0.003 & 0.526$\pm$0.003 & 0.5251$\pm$0.003 & 0.5248$\pm$0.003 & 0.5244$\pm$0.003 & 0.5237$\pm$0.003 & 0.5243$\pm$0.003 & 0.523$\pm$0.003 & 0.5216$\pm$0.003 & 0.5227$\pm$0.003 & 0.5234$\pm$0.003 & 0.5232$\pm$0.003 & 0.5221$\pm$0.003 & 0.5207$\pm$0.003 \\
# \hline
# Tianjing & 0.55$\pm$0.0031 & 0.5464$\pm$0.0031 & 0.5433$\pm$0.0031 & 0.5413$\pm$0.0031 & 0.5399$\pm$0.0031 & 0.5391$\pm$0.0031 & 0.5391$\pm$0.0031 & 0.5394$\pm$0.0031 & 0.539$\pm$0.0031 & 0.5391$\pm$0.0031 & 0.5382$\pm$0.0031 & 0.5374$\pm$0.0031 & 0.538$\pm$0.0031 & 0.5383$\pm$0.0031 & 0.5381$\pm$0.0031 & 0.5373$\pm$0.0031 & 0.5366$\pm$0.0031 \\
# \hline
# ...

# %%
for p in M['Threshold-based Method']:
    line = p
    for i, m in enumerate(M['Threshold-based Method'][p]):
        line += ' & ' + str(round(m, 4)) + '$\pm$' + str(round(M_std['Threshold-based Method'][p][i], 4))
    line += r' \\'
    print(line)
    print('\hline')
# Out:
# Beijing & 0.4457$\pm$0.0064 & 0.4417$\pm$0.0063 & 0.4384$\pm$0.0063 & 0.4364$\pm$0.0062 & 0.4348$\pm$0.0062 & 0.4341$\pm$0.0062 & 0.4339$\pm$0.0062 & 0.4335$\pm$0.0062 & 0.4329$\pm$0.0062 & 0.4335$\pm$0.0062 & 0.4323$\pm$0.0062 & 0.4312$\pm$0.0062 & 0.4321$\pm$0.0062 & 0.4326$\pm$0.0062 & 0.4325$\pm$0.0062 & 0.4316$\pm$0.0062 & 0.4305$\pm$0.0061 \\
# \hline
# Tianjing & 0.4547$\pm$0.0065 & 0.4517$\pm$0.0064 & 0.4491$\pm$0.0064 & 0.4475$\pm$0.0064 & 0.4463$\pm$0.0064 & 0.4457$\pm$0.0064 & 0.4457$\pm$0.0064 & 0.4459$\pm$0.0064 & 0.4456$\pm$0.0064 & 0.4456$\pm$0.0064 & 0.4449$\pm$0.0063 & 0.4443$\pm$0.0063 & 0.4448$\pm$0.0063 & 0.445$\pm$0.0064 & 0.4449$\pm$0.0063 & 0.4442$\pm$0.0063 & 0.4436$\pm$0.0063 \\
# \hline
# ...

# %%
for p in M['Greedy']:
    line = p
    for i, m in enumerate(M['Greedy'][p]):
        line += ' & ' + str(round(m, 4)) + '$\pm$' + str(round(M_std['Greedy'][p][i], 4))
    line += r' \\'
    print(line)
    print('\hline')
# Out:
# Beijing & 0.3691$\pm$0.0048 & 0.3658$\pm$0.0047 & 0.363$\pm$0.0047 & 0.3614$\pm$0.0047 & 0.3601$\pm$0.0047 & 0.3595$\pm$0.0046 & 0.3593$\pm$0.0046 & 0.359$\pm$0.0046 & 0.3585$\pm$0.0046 & 0.359$\pm$0.0046 & 0.358$\pm$0.0046 & 0.3571$\pm$0.0046 & 0.3578$\pm$0.0046 & 0.3583$\pm$0.0046 & 0.3582$\pm$0.0046 & 0.3574$\pm$0.0046 & 0.3565$\pm$0.0046 \\
# \hline
# Tianjing & 0.3765$\pm$0.0049 & 0.374$\pm$0.0048 & 0.3719$\pm$0.0048 & 0.3706$\pm$0.0048 & 0.3696$\pm$0.0048 & 0.3691$\pm$0.0048 & 0.3691$\pm$0.0048 & 0.3692$\pm$0.0048 & 0.369$\pm$0.0048 & 0.369$\pm$0.0048 & 0.3684$\pm$0.0048 & 0.3679$\pm$0.0048 & 0.3683$\pm$0.0048 & 0.3685$\pm$0.0048 & 0.3684$\pm$0.0048 & 0.3678$\pm$0.0048 & 0.3673$\pm$0.0047 \\
# \hline
# ...

# %%
for p in M['DeepEnergy']:
    line = p
    for i, m in enumerate(M['DeepEnergy'][p]):
        line += ' & ' + str(round(m, 4)) + '$\pm$' + str(round(M_std['DeepEnergy'][p][i], 4))
    line += r' \\'
    print(line)
    print('\hline')
# Out:
# Beijing & 0.2438$\pm$0.0069 & 0.2416$\pm$0.0069 & 0.2398$\pm$0.0068 & 0.2386$\pm$0.0068 & 0.2378$\pm$0.0068 & 0.2374$\pm$0.0067 & 0.2373$\pm$0.0067 & 0.2371$\pm$0.0067 & 0.2368$\pm$0.0067 & 0.2371$\pm$0.0067 & 0.2364$\pm$0.0067 & 0.2358$\pm$0.0067 & 0.2363$\pm$0.0067 & 0.2366$\pm$0.0067 & 0.2366$\pm$0.0067 & 0.2361$\pm$0.0067 & 0.2354$\pm$0.0067 \\
# \hline
# Tianjing & 0.2487$\pm$0.0071 & 0.247$\pm$0.007 & 0.2456$\pm$0.007 & 0.2447$\pm$0.0069 & 0.2441$\pm$0.0069 & 0.2438$\pm$0.0069 & 0.2437$\pm$0.0069 & 0.2438$\pm$0.0069 & 0.2437$\pm$0.0069 & 0.2437$\pm$0.0069 & 0.2433$\pm$0.0069 & 0.243$\pm$0.0069 & 0.2433$\pm$0.0069 & 0.2434$\pm$0.0069 & 0.2433$\pm$0.0069 & 0.2429$\pm$0.0069 & 0.2426$\pm$0.0069 \\
# \hline
# ...
