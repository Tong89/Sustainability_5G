# %%
import numpy as np
import pandas as pd
Network_Traffic = np.load('Network_Traffic.npy', allow_pickle=True).item()
Network_Energy = np.load('Network_Energy.npy', allow_pickle=True).item()
Network_Energy_std = np.load('Network_Energy_std.npy', allow_pickle=True).item()
Network_Carbon = np.load('Network_Carbon.npy', allow_pickle=True).item()
Network_Carbon_std = np.load('Network_Carbon_std.npy', allow_pickle=True).item()
Additional_Carbon = np.load('Additional_Carbon_Province.npy', allow_pickle=True).item()
Additional_Carbon_std = np.load('Additional_Carbon_std_Province.npy', allow_pickle=True).item()
Wasted_Energy = np.load('Wasted_Energy_Province.npy', allow_pickle=True).item()
Wasted_Energy_std = np.load('Wasted_Energy_std_Province.npy', allow_pickle=True).item()
Time_list_After5G = []
for year in ['2021', '2022', '2023']:
    for month in range(1, 13):
        if month < 10:
            Time_list_After5G.append(f'{year}-0{month}')
        else:
            Time_list_After5G.append(f'{year}-{month}')
len(Time_list_After5G), len(Network_Traffic['Beijing'])
# Out:
# (36, 36)

# %%
for p in Network_Traffic:
    law = p
    for i in range(24, 36):
        law += f' & {round(Network_Traffic[p][i]*30, 2)}$\pm${round(Network_Traffic[p][i]*30*0.03, 2)}'
    law += '\\\\ \n\hline'
    print(law)
# Out:
# Beijing & 476.7$\pm$14.3 & 523.56$\pm$15.71 & 577.25$\pm$17.32 & 638.25$\pm$19.15 & 707.01$\pm$21.21 & 784.0$\pm$23.52 & 869.67$\pm$26.09 & 964.5$\pm$28.94 & 1068.95$\pm$32.07 & 1183.47$\pm$35.5 & 1308.54$\pm$39.26 & 1444.61$\pm$43.34\\
# \hline
# Tianjing & 227.71$\pm$6.83 & 252.31$\pm$7.57 & 280.46$\pm$8.41 & 312.38$\pm$9.37 & 348.32$\pm$10.45 & 388.52$\pm$11.66 & 433.2$\pm$13.0 & 482.6$\pm$14.48 & 536.97$\pm$16.11 & 596.53$\pm$17.9 & 661.52$\pm$19.85 & 732.17$\pm$21.97\\
# \hline
# Hebei & 1082.0$\pm$32.46 & 1192.4$\pm$35.77 & 1318.75$\pm$39.56 & 1462.12$\pm$43.86 & 1623.59$\pm$48.71 & 1804.22$\pm$54.13 & 2005.08$\pm$60.15 & 2227.26$\pm$66.82 & 2471.83$\pm$74.15 & 2739.84$\pm$82.2 & 3032.39$\pm$90.97 & 3350.54$\pm$100.52\\
# \hline
# Shanxi & 548.73$\pm$16.46 & 608.0$\pm$18.24 & 675.69$\pm$20.27 & 752.37$\pm$22.57 & 838.58$\pm$25.16 & 934.88$\pm$28.05 & 1041.84$\pm$31.26 & 1160.0$\pm$34.8 & 1289.92$\pm$38.7 & 1432.17$\pm$42.97 & 1587.29$\pm$47.62 & 1755.85$\pm$52.68\\
# \hline
# Inner Mongolia & 391.08$\pm$11.73 & 432.15$\pm$12.96 & 479.04$\pm$14.37 & 532.14$\pm$15.96 & 591.84$\pm$17.76 & 658.51$\pm$19.76 & 732.55$\pm$21.98 & 814.34$\pm$24.43 & 904.26$\pm$27.13 & 1002.7$\pm$30.08 & 1110.05$\pm$33.3 & 1226.68$\pm$36.8\\
# \hline
# \hline
# Xinjiang & 393.71$\pm$11.81 & 436.17$\pm$13.09 & 484.69$\pm$14.54 & 539.67$\pm$16.19 & 601.5$\pm$18.05 & 670.59$\pm$20.12 & 747.34$\pm$22.42 & 832.15$\pm$24.96 & 925.42$\pm$27.76 & 1027.56$\pm$30.83 & 1138.96$\pm$34.17 & 1260.03$\pm$37.8\\
# \hline

# %%
Energy_all = {'2021':0, '2022':0, '2023':0}
Energy_all_std = {'2021':0, '2022':0, '2023':0}
for p in Network_Energy:
    law = p
    for i in range(3):
        value = 0
        value_std = 0
        for j in range(12):
            value += Network_Energy[p][i*12+j]*30
            value_std += Network_Energy_std[p][i*12+j]*30
        law += f' & {round(value/1000, 2)}$\pm${round(value_std/1000, 2)}'
        Energy_all['202'+str(i+1)] += value
        Energy_all_std['202'+str(i+1)] += value_std
    law += '\\\\ \n\hline'
    print(law)
print(f"All of China & {round(Energy_all['2021']/1000, 2)}$\pm${round(Energy_all_std['2021']/1000, 2)} & {round(Energy_all['2022']/1000, 2)}$\pm${round(Energy_all_std['2022']/1000, 2)} & {round(Energy_all['2023']/1000, 2)}$\pm${round(Energy_all_std['2023']/1000, 2)}")
# Out:
# Beijing & 1116.67$\pm$4.57 & 1130.76$\pm$5.06 & 1253.08$\pm$9.31\\
# \hline
# Tianjing & 677.3$\pm$2.85 & 684.21$\pm$3.1 & 748.28$\pm$5.43\\
# \hline
# Hebei & 3606.84$\pm$10.22 & 3644.1$\pm$11.45 & 3960.27$\pm$21.94\\
# \hline
# Shanxi & 2263.84$\pm$7.3 & 2282.79$\pm$7.95 & 2449.12$\pm$13.66\\
# \hline
# Inner Mongolia & 1339.32$\pm$4.87 & 1352.51$\pm$5.33 & 1466.14$\pm$9.3\\
# \hline
# Liaoning & 1998.27$\pm$7.83 & 2021.1$\pm$8.63 & 2225.03$\pm$15.74\\
# \hline
# Jilin & 1000.49$\pm$4.38 & 1013.47$\pm$4.84 & 1125.06$\pm$8.81\\
# \hline
# Heilongjiang & 1746.02$\pm$6.02 & 1761.28$\pm$6.53 & 1897.93$\pm$11.17\\
# \hline
# Shanghai & 1541.67$\pm$5.05 & 1554.21$\pm$5.48 & 1681.25$\pm$9.86\\
# \hline
# Jiangsu & 4641.51$\pm$12.15 & 4686.25$\pm$13.62 & 5067.6$\pm$26.17\\
# \hline
# Zhejiang & 4133.64$\pm$8.52 & 4173.9$\pm$9.84 & 4518.92$\pm$21.12\\
# \hline
# Anhui & 2805.45$\pm$6.71 & 2833.9$\pm$7.64 & 3089.76$\pm$15.98\\
# \hline
# Fujian & 2967.5$\pm$6.59 & 2989.65$\pm$7.34 & 3194.71$\pm$14.26\\
# \hline
# Jiangxi & 2857.09$\pm$6.45 & 2875.7$\pm$7.07 & 3016.96$\pm$11.77\\
# \hline
# Shandong & 4632.22$\pm$12.08 & 4686.5$\pm$13.85 & 5139.0$\pm$28.55\\
# \hline
# Henan & 3290.93$\pm$10.12 & 3340.16$\pm$11.74 & 3781.06$\pm$26.33\\
# \hline
# Hubei & 3073.59$\pm$7.21 & 3099.73$\pm$8.08 & 3327.01$\pm$15.65\\
# \hline
# Hunan & 2887.99$\pm$9.2 & 2917.95$\pm$10.23 & 3197.02$\pm$19.87\\
# \hline
# Guangdong & 6159.93$\pm$14.25 & 6234.9$\pm$16.64 & 6830.88$\pm$35.67\\
# \hline
# Guangxi & 2214.26$\pm$7.89 & 2244.21$\pm$8.92 & 2503.33$\pm$17.83\\
# \hline
# Hainan & 550.64$\pm$3.2 & 555.44$\pm$3.39 & 596.26$\pm$5.0\\
# \hline
# Chongqing & 2098.21$\pm$6.55 & 2117.15$\pm$7.2 & 2277.38$\pm$12.72\\
# \hline
# Sichuan & 4185.95$\pm$11.27 & 4236.27$\pm$12.94 & 4676.94$\pm$27.57\\
# \hline
# Guizhou & 2831.47$\pm$7.2 & 2851.54$\pm$7.88 & 3012.65$\pm$13.29\\
# \hline
# Yunnan & 3675.93$\pm$9.61 & 3697.31$\pm$10.33 & 3895.8$\pm$17.03\\
# \hline
# Tibet & 407.55$\pm$2.35 & 409.2$\pm$2.42 & 421.97$\pm$2.95\\
# \hline
# Shaanxi & 2149.09$\pm$5.58 & 2169.94$\pm$6.27 & 2343.94$\pm$12.07\\
# \hline
# Gansu & 1298.18$\pm$4.75 & 1311.81$\pm$5.24 & 1437.1$\pm$9.69\\
# \hline
# Qinghai & 360.95$\pm$1.9 & 364.38$\pm$2.04 & 392.39$\pm$3.18\\
# \hline
# Ningxia & 444.71$\pm$2.12 & 448.82$\pm$2.28 & 481.4$\pm$3.54\\
# \hline
# Xinjiang & 1337.87$\pm$5.36 & 1353.1$\pm$5.89 & 1484.85$\pm$10.53\\
# \hline
# All of China & 74295.13$\pm$214.15 & 75042.23$\pm$239.24 & 81493.12$\pm$455.99

# %%
Carbon_all = {'2021':0, '2022':0, '2023':0}
Carbon_all_std = {'2021':0, '2022':0, '2023':0}
for p in Network_Carbon:
    law = p
    for i in range(3):
        value = 0
        value_std = 0
        for j in range(12):
            value += Network_Carbon[p][i*12+j]*30
            value_std += Network_Carbon_std[p][i*12+j]*30
        law += f' & {round(value/1000, 2)}$\pm${round(value_std/1000, 2)}'
        Carbon_all['202'+str(i+1)] += value
        Carbon_all_std['202'+str(i+1)] += value_std
    law += '\\\\ \n\hline'
    print(law)
print(f"All of China & {round(Carbon_all['2021']/1000, 2)}$\pm${round(Carbon_all_std['2021']/1000, 2)} & {round(Carbon_all['2022']/1000, 2)}$\pm${round(Carbon_all_std['2022']/1000, 2)} & {round(Carbon_all['2023']/1000, 2)}$\pm${round(Carbon_all_std['2023']/1000, 2)}")
# Out:
# Beijing & 759.34$\pm$44.26 & 768.92$\pm$45.13 & 852.1$\pm$52.66\\
# \hline
# Tianjing & 460.57$\pm$26.9 & 465.26$\pm$27.33 & 508.83$\pm$31.35\\
# \hline
# Hebei & 2452.65$\pm$139.69 & 2477.99$\pm$141.95 & 2692.99$\pm$161.07\\
# \hline
# Shanxi & 1539.41$\pm$88.32 & 1552.3$\pm$89.48 & 1665.4$\pm$99.67\\
# \hline
# Inner Mongolia & 910.74$\pm$52.64 & 919.71$\pm$53.46 & 996.98$\pm$60.47\\
Method_list = list(Additional_Carbon.keys())
Province_list = list(Additional_Carbon['Without Method'].keys())
data_Energy = pd.DataFrame([], index=Province_list, columns=Method_list)
data_Carbon = pd.DataFrame([], index=Province_list, columns=Method_list)
for m in Additional_Carbon:
    for p in Additional_Carbon[m]:
        data_Energy.loc[p, m] = f'{int(Wasted_Energy[m][p])/1000}+-{int(Wasted_Energy_std[m][p])/1000}'
        data_Carbon.loc[p, m] = f'{int(Additional_Carbon[m][p])/1000}+-{int(Additional_Carbon_std[m][p])/1000}'
data_Energy.to_csv('data_Energy.csv')
data_Carbon.to_csv('data_Carbon.csv')

# %%
print(Method_list)
# Out:
# ['Without Method', 'Threshold-Based Method', 'Heuristic-Based Method', 'RL-Based Method']

# %%
AC = {'Without Method':0, 'Threshold-Based Method':0, 'Heuristic-Based Method':0, 'RL-Based Method':0}
AC_std = {'Without Method':0, 'Threshold-Based Method':0, 'Heuristic-Based Method':0, 'RL-Based Method':0}
for p in Province_list:
    AC[Method_list[0]] += Additional_Carbon[Method_list[0]][p]
    AC[Method_list[1]] += Additional_Carbon[Method_list[1]][p]
    AC[Method_list[2]] += Additional_Carbon[Method_list[2]][p]
    AC[Method_list[3]] += Additional_Carbon[Method_list[3]][p]
    AC_std[Method_list[0]] += Additional_Carbon_std[Method_list[0]][p]
    AC_std[Method_list[1]] += Additional_Carbon_std[Method_list[1]][p]
    AC_std[Method_list[2]] += Additional_Carbon_std[Method_list[2]][p]
    AC_std[Method_list[3]] += Additional_Carbon_std[Method_list[3]][p]
    print('\hline')
    print(f'{p} & {int(Additional_Carbon[Method_list[0]][p])/1000}$\pm${int(Additional_Carbon_std[Method_list[0]][p])/1000}  & {int(Additional_Carbon[Method_list[1]][p])/1000}$\pm${int(Additional_Carbon_std[Method_list[1]][p])/1000}  & {int(Additional_Carbon[Method_list[2]][p])/1000}$\pm${int(Additional_Carbon_std[Method_list[2]][p])/1000}  & {int(Additional_Carbon[Method_list[3]][p])/1000}$\pm${int(Additional_Carbon_std[Method_list[3]][p])/1000}  \\\\')
print('\hline')
print(f'All over China & {int(AC[Method_list[0]])/1000}$\pm${int(AC_std[Method_list[0]])/1000} & {int(AC[Method_list[1]])/1000}$\pm${int(AC_std[Method_list[1]])/1000} & {int(AC[Method_list[2]])/1000}$\pm${int(AC_std[Method_list[2]])/1000} & {int(AC[Method_list[3]])/1000}$\pm${int(AC_std[Method_list[3]])/1000} \\\\')
# Out:
# \hline
# Beijing & 522.607$\pm$21.703  & 305.581$\pm$11.299  & 143.671$\pm$4.287  & 4.592$\pm$0.357  \\
# \hline
# Tianjing & 319.228$\pm$14.464  & 185.326$\pm$7.511  & 85.617$\pm$2.208  & 2.581$\pm$0.126  \\
# \hline
# Hebei & 836.627$\pm$35.177  & 248.501$\pm$7.675  & 46.549$\pm$1.146  & 0.0$\pm$0.0  \\
# \hline
# Shanxi & 649.464$\pm$29.644  & 252.944$\pm$9.349  & 43.173$\pm$0.963  & 0.0$\pm$0.0  \\
# \hline
# Inner Mongolia & 434.953$\pm$17.666  & 194.915$\pm$7.172  & 37.493$\pm$0.475  & 0.0$\pm$0.0  \\
# \hline
# Liaoning & 368.728$\pm$14.193  & 75.564$\pm$1.668  & 16.662$\pm$2.113  & 0.0$\pm$0.0  \\
# \hline
# Qinghai & 44.888$\pm$1.383  & 8.16$\pm$0.169  & 1.401$\pm$0.723  & 0.0$\pm$0.0  \\
# \hline
# Ningxia & 157.105$\pm$6.819  & 75.137$\pm$2.41  & 18.599$\pm$0.212  & 0.0$\pm$0.0  \\
# \hline
# Xinjiang & 99.964$\pm$3.338  & 19.448$\pm$0.756  & 3.152$\pm$1.626  & 0.0$\pm$0.0  \\
# \hline
# All over China & 23815.926$\pm$1067.671 & 11336.618$\pm$463.515 & 4235.346$\pm$173.034 & 177.925$\pm$7.695 \\

# %%
WE = {'Without Method':0, 'Threshold-Based Method':0, 'Heuristic-Based Method':0, 'RL-Based Method':0}
WE_std = {'Without Method':0, 'Threshold-Based Method':0, 'Heuristic-Based Method':0, 'RL-Based Method':0}
for p in Province_list:
    WE[Method_list[0]] += Wasted_Energy[Method_list[0]][p]
    WE[Method_list[1]] += Wasted_Energy[Method_list[1]][p]
    WE[Method_list[2]] += Wasted_Energy[Method_list[2]][p]
    WE[Method_list[3]] += Wasted_Energy[Method_list[3]][p]
    WE_std[Method_list[0]] += Wasted_Energy_std[Method_list[0]][p]
    WE_std[Method_list[1]] += Wasted_Energy_std[Method_list[1]][p]
    WE_std[Method_list[2]] += Wasted_Energy_std[Method_list[2]][p]
    WE_std[Method_list[3]] += Wasted_Energy_std[Method_list[3]][p]
    print('\hline')
    print(f'{p} & {int(Wasted_Energy[Method_list[0]][p])/1000}$\pm${int(Wasted_Energy_std[Method_list[0]][p])/1000} & {int(Wasted_Energy[Method_list[1]][p])/1000}$\pm${int(Wasted_Energy_std[Method_list[1]][p])/1000} & {int(Wasted_Energy[Method_list[2]][p])/1000}$\pm${int(Wasted_Energy_std[Method_list[2]][p])/1000} & {int(Wasted_Energy[Method_list[3]][p])/1000}$\pm${int(Wasted_Energy_std[Method_list[3]][p])/1000} \\\\')
print('\hline')
print(f'All over China & {int(WE[Method_list[0]])/1000}$\pm${int(WE_std[Method_list[0]])/1000} & {int(WE[Method_list[1]])/1000}$\pm${int(WE_std[Method_list[1]])/1000} & {int(WE[Method_list[2]])/1000}$\pm${int(WE_std[Method_list[2]])/1000} & {int(WE[Method_list[3]])/1000}$\pm${int(WE_std[Method_list[3]])/1000} \\\\')
# Out:
# \hline
# Beijing & 768.541$\pm$9.86 & 449.383$\pm$7.888 & 211.281$\pm$5.371 & 6.754$\pm$0.826 \\
# \hline
# Tianjing & 469.453$\pm$4.317 & 272.539$\pm$3.869 & 125.908$\pm$3.688 & 3.796$\pm$0.394 \\
# \hline
# Hebei & 1230.334$\pm$14.89 & 365.443$\pm$8.676 & 68.454$\pm$2.389 & 0.0$\pm$0.0 \\
# \hline
# Shanxi & 955.095$\pm$8.291 & 371.977$\pm$6.621 & 63.489$\pm$2.011 & 0.0$\pm$0.0 \\
# \hline
# Inner Mongolia & 639.636$\pm$8.635 & 286.639$\pm$5.134 & 55.136$\pm$2.38 & 0.0$\pm$0.0 \\
# \hline
# Liaoning & 542.248$\pm$8.615 & 111.124$\pm$3.661 & 24.502$\pm$3.331 & 0.0$\pm$0.0 \\
# \hline
# Jilin & 237.954$\pm$4.282 & 44.175$\pm$0.928 & 10.688$\pm$1.298 & 0.0$\pm$0.0 \\
# \hline
# Ningxia & 231.037$\pm$2.565 & 110.495$\pm$2.508 & 27.352$\pm$1.222 & 0.0$\pm$0.0 \\
# \hline
# Xinjiang & 147.006$\pm$3.19 & 28.6$\pm$0.446 & 4.635$\pm$2.365 & 0.0$\pm$0.0 \\
# \hline
# All over China & 35023.421$\pm$327.353 & 16671.497$\pm$233.626 & 6228.45$\pm$130.595 & 261.654$\pm$19.321 \\

# %%
import numpy as np
Carbon_Reduction = np.load('Carbon_Reduction.npy', allow_pickle=True).item()
Carbon_Reduction_std = np.load('Carbon_Reduction_std.npy', allow_pickle=True).item()
Energy_Reduction = np.load('Energy_Reduction.npy', allow_pickle=True).item()
Energy_Reduction_std = np.load('Energy_Reduction_std.npy', allow_pickle=True).item()
Method_list = list(Carbon_Reduction['2021'].keys())
Province_list = list(Carbon_Reduction['2021']['Threshold-Based Method'].keys())

# %%
Energy_Reduction['2021'].keys()
# Out:
# dict_keys(['Threshold-Based Method', 'Heuristic-Based Method', 'RL-Based Method'])

# %%
for year in ['2021']:
    print(year, '\n\n\n')
    CR = {'Threshold-Based Method':0, 'Heuristic-Based Method':0, 'RL-Based Method':0}
    CR_std = {'Threshold-Based Method':0, 'Heuristic-Based Method':0, 'RL-Based Method':0}
    for p in Province_list:
        CR[Method_list[0]] += Carbon_Reduction[year][Method_list[0]][p]
        CR[Method_list[1]] += Carbon_Reduction[year][Method_list[1]][p]
        CR[Method_list[2]] += Carbon_Reduction[year][Method_list[2]][p]
        CR_std[Method_list[0]] += Carbon_Reduction_std[year][Method_list[0]][p]
        CR_std[Method_list[1]] += Carbon_Reduction_std[year][Method_list[1]][p]
        CR_std[Method_list[2]] += Carbon_Reduction_std[year][Method_list[2]][p]
        print('\hline')
        print(f'{p} & {round(Carbon_Reduction[year][Method_list[0]][p]/1000, 3)}$\pm${round(Carbon_Reduction_std[year][Method_list[0]][p]/1000, 3)} & {round(Carbon_Reduction[year][Method_list[1]][p]/1000, 3)}$\pm${round(Carbon_Reduction_std[year][Method_list[1]][p]/1000, 3)} & {round(Carbon_Reduction[year][Method_list[2]][p]/1000, 3)}$\pm${round(Carbon_Reduction_std[year][Method_list[2]][p]/1000, 3)} \\\\')
    print('\hline')
    print(f'All over China & {round(CR[Method_list[0]]/1000, 3)}$\pm${round(CR_std[Method_list[0]]/1000, 3)} & {round(CR[Method_list[1]]/1000, 3)}$\pm${round(CR_std[Method_list[1]]/1000, 3)} & {round(CR[Method_list[2]]/1000, 3)}$\pm${round(CR_std[Method_list[2]]/1000, 3)} \\\\')
# Out:
# 2021
#
#
#
# \hline
# Beijing & 113.212$\pm$6.012 & 206.025$\pm$10.941 & 357.881$\pm$19.005 \\
# \hline
# Tianjing & 71.688$\pm$3.91 & 130.46$\pm$7.115 & 226.619$\pm$12.36 \\
# \hline
# Hebei & 381.211$\pm$20.326 & 693.736$\pm$36.989 & 1205.07$\pm$64.253 \\
# \hline
# Shanxi & 246.157$\pm$13.439 & 447.961$\pm$24.456 & 778.14$\pm$42.482 \\
# \hline
# Inner Mongolia & 143.018$\pm$7.775 & 260.267$\pm$14.15 & 452.103$\pm$24.58 \\
# \hline
# Liaoning & 209.421$\pm$11.318 & 381.109$\pm$20.597 & 662.014$\pm$35.779 \\
# \hline
# Jilin & 102.375$\pm$5.491 & 186.303$\pm$9.992 & 323.623$\pm$17.358 \\
# \hline
# Heilongjiang & 187.061$\pm$10.171 & 340.417$\pm$18.509 & 591.329$\pm$32.152 \\
# \hline
# Shanghai & 162.226$\pm$8.679 & 295.222$\pm$15.795 & 512.822$\pm$27.437 \\
# \hline
# Jiangsu & 500.884$\pm$26.949 & 911.519$\pm$49.042 & 1583.376$\pm$85.189 \\
# \hline
# Zhejiang & 446.032$\pm$23.734 & 811.698$\pm$43.192 & 1409.98$\pm$75.028 \\
# \hline
# Anhui & 300.536$\pm$16.031 & 546.921$\pm$29.173 & 950.043$\pm$50.675 \\
# \hline
# Fujian & 324.297$\pm$17.424 & 590.162$\pm$31.708 & 1025.154$\pm$55.079 \\
# \hline
# Jiangxi & 315.382$\pm$17.073 & 573.938$\pm$31.069 & 996.973$\pm$53.97 \\
# \hline
# Shandong & 491.851$\pm$26.215 & 895.08$\pm$47.706 & 1554.82$\pm$82.869 \\
# \hline
# Henan & 334.855$\pm$17.514 & 609.375$\pm$31.873 & 1058.529$\pm$55.365 \\
# \hline
# Hubei & 333.443$\pm$17.888 & 606.806$\pm$32.553 & 1054.068$\pm$56.548 \\
# \hline
# Hunan & 305.15$\pm$16.34 & 555.318$\pm$29.736 & 964.627$\pm$51.653 \\
# \hline
# Guangdong & 652.722$\pm$34.571 & 1187.837$\pm$62.913 & 2063.36$\pm$109.284 \\
# \hline
# Guangxi & 231.728$\pm$12.433 & 421.703$\pm$22.625 & 732.529$\pm$39.302 \\
# \hline
# Hainan & 59.229$\pm$3.351 & 107.787$\pm$6.098 & 187.234$\pm$10.594 \\
# \hline
# Chongqing & 228.378$\pm$12.447 & 415.607$\pm$22.652 & 721.94$\pm$39.348 \\
# \hline
# Sichuan & 441.848$\pm$23.469 & 804.083$\pm$42.709 & 1396.752$\pm$74.189 \\
# \hline
# Guizhou & 312.687$\pm$17.019 & 569.035$\pm$30.972 & 988.455$\pm$53.8 \\
# \hline
# Yunnan & 407.881$\pm$22.292 & 742.269$\pm$40.568 & 1289.377$\pm$70.47 \\
# \hline
# Tibet & 46.126$\pm$2.686 & 83.942$\pm$4.889 & 145.813$\pm$8.492 \\
# \hline
# Shaanxi & 229.54$\pm$12.256 & 417.722$\pm$22.304 & 725.613$\pm$38.744 \\
# \hline
# Gansu & 137.524$\pm$7.434 & 250.269$\pm$13.528 & 434.735$\pm$23.499 \\
# \hline
# Qinghai & 38.898$\pm$2.176 & 70.788$\pm$3.959 & 122.964$\pm$6.877 \\
# \hline
# Ningxia & 48.223$\pm$2.692 & 87.756$\pm$4.898 & 152.439$\pm$8.509 \\
# \hline
# Xinjiang & 141.318$\pm$7.684 & 257.173$\pm$13.984 & 446.729$\pm$24.29 \\
# \hline
# All over China & 7944.901$\pm$426.799 & 14458.289$\pm$776.697 & 25115.113$\pm$1349.179 \\

# %%
for year in ['2022']:
    print(year, '\n\n\n')
    CR = {'Threshold-Based Method':0, 'Heuristic-Based Method':0, 'RL-Based Method':0}
    CR_std = {'Threshold-Based Method':0, 'Heuristic-Based Method':0, 'RL-Based Method':0}
    for p in Province_list:
        CR[Method_list[0]] += Carbon_Reduction[year][Method_list[0]][p]
        CR[Method_list[1]] += Carbon_Reduction[year][Method_list[1]][p]
        CR[Method_list[2]] += Carbon_Reduction[year][Method_list[2]][p]
        CR_std[Method_list[0]] += Carbon_Reduction_std[year][Method_list[0]][p]
        CR_std[Method_list[1]] += Carbon_Reduction_std[year][Method_list[1]][p]
        CR_std[Method_list[2]] += Carbon_Reduction_std[year][Method_list[2]][p]
        print('\hline')
        print(f'{p} & {round(Carbon_Reduction[year][Method_list[0]][p]/1000, 3)}$\pm${round(Carbon_Reduction_std[year][Method_list[0]][p]/1000, 3)} & {round(Carbon_Reduction[year][Method_list[1]][p]/1000, 3)}$\pm${round(Carbon_Reduction_std[year][Method_list[1]][p]/1000, 3)} & {round(Carbon_Reduction[year][Method_list[2]][p]/1000, 3)}$\pm${round(Carbon_Reduction_std[year][Method_list[2]][p]/1000, 3)} \\\\')
    print('\hline')
    print(f'All over China & {round(CR[Method_list[0]]/1000, 3)}$\pm${round(CR_std[Method_list[0]]/1000, 3)} & {round(CR[Method_list[1]]/1000, 3)}$\pm${round(CR_std[Method_list[1]]/1000, 3)} & {round(CR[Method_list[2]]/1000, 3)}$\pm${round(CR_std[Method_list[2]]/1000, 3)} \\\\')
# Out:
# 2022
#
#
#
# \hline
# Beijing & 110.464$\pm$5.769 & 201.024$\pm$10.498 & 349.193$\pm$18.236 \\
# \hline
# Tianjing & 70.318$\pm$3.786 & 127.967$\pm$6.89 & 222.288$\pm$11.969 \\
# \hline
# Hebei & 373.951$\pm$19.694 & 680.523$\pm$35.839 & 1182.118$\pm$62.255 \\
# \hline
# Shanxi & 242.432$\pm$13.11 & 441.182$\pm$23.859 & 766.365$\pm$41.444 \\
# \hline
# Inner Mongolia & 140.434$\pm$7.546 & 255.564$\pm$13.732 & 443.933$\pm$23.854 \\
# \hline
# Liaoning & 204.927$\pm$10.92 & 372.931$\pm$19.872 & 647.809$\pm$34.519 \\
# \hline
# Jilin & 99.845$\pm$5.265 & 181.7$\pm$9.581 & 315.627$\pm$16.643 \\
# \hline
# Heilongjiang & 184.057$\pm$9.907 & 334.95$\pm$18.03 & 581.834$\pm$31.319 \\
# \hline
# Shanghai & 159.727$\pm$8.459 & 290.675$\pm$15.393 & 504.924$\pm$26.739 \\
# \hline
# Jiangsu & 492.119$\pm$26.188 & 895.567$\pm$47.657 & 1555.666$\pm$82.784 \\
# \hline
# Zhejiang & 438.147$\pm$23.052 & 797.349$\pm$41.95 & 1385.054$\pm$72.87 \\
# \hline
# Anhui & 294.916$\pm$15.544 & 536.694$\pm$28.288 & 932.277$\pm$49.138 \\
# \hline
# Fujian & 319.909$\pm$17.039 & 582.176$\pm$31.009 & 1011.283$\pm$53.864 \\
# \hline
# Jiangxi & 311.811$\pm$16.761 & 567.44$\pm$30.503 & 985.684$\pm$52.986 \\
# \hline
# Shandong & 481.253$\pm$25.299 & 875.794$\pm$46.04 & 1521.32$\pm$79.975 \\
# \hline
# Henan & 325.137$\pm$16.669 & 591.691$\pm$30.335 & 1027.812$\pm$52.694 \\
# \hline
# Hubei & 328.318$\pm$17.441 & 597.479$\pm$31.74 & 1037.865$\pm$55.135 \\
# \hline
# Hunan & 299.22$\pm$15.816 & 544.527$\pm$28.782 & 945.883$\pm$49.997 \\
# \hline
# Guangdong & 638.209$\pm$33.325 & 1161.425$\pm$60.646 & 2017.482$\pm$105.346 \\
# \hline
# Guangxi & 225.841$\pm$11.913 & 410.991$\pm$21.68 & 713.921$\pm$37.66 \\
# \hline
# Hainan & 58.292$\pm$3.264 & 106.081$\pm$5.94 & 184.271$\pm$10.318 \\
# \hline
# Chongqing & 224.669$\pm$12.12 & 408.858$\pm$22.056 & 710.216$\pm$38.313 \\
# \hline
# Sichuan & 431.935$\pm$22.606 & 786.044$\pm$41.139 & 1365.416$\pm$71.461 \\
# \hline
# Guizhou & 308.795$\pm$16.678 & 561.952$\pm$30.352 & 976.152$\pm$52.723 \\
# \hline
# Yunnan & 403.642$\pm$21.921 & 734.556$\pm$39.893 & 1275.979$\pm$69.296 \\
# \hline
# Tibet & 45.811$\pm$2.656 & 83.368$\pm$4.834 & 144.817$\pm$8.397 \\
# \hline
# Shaanxi & 225.492$\pm$11.903 & 410.355$\pm$21.662 & 712.816$\pm$37.629 \\
# \hline
# Gansu & 134.826$\pm$7.193 & 245.359$\pm$13.089 & 426.207$\pm$22.737 \\
# \hline
# Qinghai & 38.235$\pm$2.113 & 69.581$\pm$3.845 & 120.867$\pm$6.679 \\
# \hline
# Ningxia & 47.426$\pm$2.618 & 86.307$\pm$4.765 & 149.921$\pm$8.277 \\
# \hline
# Xinjiang & 138.334$\pm$7.418 & 251.742$\pm$13.5 & 437.295$\pm$23.451 \\
# \hline
# All over China & 7798.493$\pm$413.996 & 14191.853$\pm$753.398 & 24652.295$\pm$1308.707 \\

# %%
for year in ['2023']:
    print(year, '\n\n\n')
    CR = {'Threshold-Based Method':0, 'Heuristic-Based Method':0, 'RL-Based Method':0}
    CR_std = {'Threshold-Based Method':0, 'Heuristic-Based Method':0, 'RL-Based Method':0}
    for p in Province_list:
        CR[Method_list[0]] += Carbon_Reduction[year][Method_list[0]][p]
        CR[Method_list[1]] += Carbon_Reduction[year][Method_list[1]][p]
        CR[Method_list[2]] += Carbon_Reduction[year][Method_list[2]][p]
        CR_std[Method_list[0]] += Carbon_Reduction_std[year][Method_list[0]][p]
        CR_std[Method_list[1]] += Carbon_Reduction_std[year][Method_list[1]][p]
        CR_std[Method_list[2]] += Carbon_Reduction_std[year][Method_list[2]][p]
        print('\hline')
        print(f'{p} & {round(Carbon_Reduction[year][Method_list[0]][p]/1000, 3)}$\pm${round(Carbon_Reduction_std[year][Method_list[0]][p]/1000, 3)} & {round(Carbon_Reduction[year][Method_list[1]][p]/1000, 3)}$\pm${round(Carbon_Reduction_std[year][Method_list[1]][p]/1000, 3)} & {round(Carbon_Reduction[year][Method_list[2]][p]/1000, 3)}$\pm${round(Carbon_Reduction_std[year][Method_list[2]][p]/1000, 3)} \\\\')
    print('\hline')
    print(f'All over China & {round(CR[Method_list[0]]/1000, 3)}$\pm${round(CR_std[Method_list[0]]/1000, 3)} & {round(CR[Method_list[1]]/1000, 3)}$\pm${round(CR_std[Method_list[1]]/1000, 3)} & {round(CR[Method_list[2]]/1000, 3)}$\pm${round(CR_std[Method_list[2]]/1000, 3)} \\\\')
# Out:
# 2023
#
#
#
# \hline
# \hline
# Qinghai & 33.082$\pm$1.626 & 60.203$\pm$2.96 & 104.578$\pm$5.142 \\
# \hline
# Ningxia & 41.444$\pm$2.066 & 75.42$\pm$3.76 & 131.01$\pm$6.532 \\
# \hline
# Xinjiang & 114.093$\pm$5.26 & 207.629$\pm$9.573 & 360.666$\pm$16.629 \\
# \hline
# All over China & 6611.755$\pm$310.196 & 12032.202$\pm$564.502 & 20900.822$\pm$980.581 \\

# %%
for year in ['2021']:
    print(year, '\n\n\n')
    ER = {'Threshold-Based Method':0, 'Heuristic-Based Method':0, 'RL-Based Method':0}
    ER_std = {'Threshold-Based Method':0, 'Heuristic-Based Method':0, 'RL-Based Method':0}
    for p in Province_list:
        ER[Method_list[0]] += Energy_Reduction[year][Method_list[0]][p]
        ER[Method_list[1]] += Energy_Reduction[year][Method_list[1]][p]
        ER[Method_list[2]] += Energy_Reduction[year][Method_list[2]][p]
        ER_std[Method_list[0]] += Energy_Reduction_std[year][Method_list[0]][p]
        ER_std[Method_list[1]] += Energy_Reduction_std[year][Method_list[1]][p]
        ER_std[Method_list[2]] += Energy_Reduction_std[year][Method_list[2]][p]
        print('\hline')
        print(f'{p} & {round(Energy_Reduction[year][Method_list[0]][p]/1000, 3)}$\pm${round(Energy_Reduction_std[year][Method_list[0]][p]/1000, 3)} & {round(Energy_Reduction[year][Method_list[1]][p]/1000, 3)}$\pm${round(Energy_Reduction_std[year][Method_list[1]][p]/1000, 3)} & {round(Energy_Reduction[year][Method_list[2]][p]/1000, 3)}$\pm${round(Energy_Reduction_std[year][Method_list[2]][p]/1000, 3)} \\\\')
    print('\hline')
    print(f'All over China & {round(ER[Method_list[0]]/1000, 3)}$\pm${round(ER_std[Method_list[0]]/1000, 3)} & {round(ER[Method_list[1]]/1000, 3)}$\pm${round(ER_std[Method_list[1]]/1000, 3)} & {round(ER[Method_list[2]]/1000, 3)}$\pm${round(ER_std[Method_list[2]]/1000, 3)} \\\\')
# Out:
# 2021
#
#
#
# \hline
# Beijing & 166.488$\pm$0.144 & 302.978$\pm$0.262 & 526.296$\pm$0.456 \\
# \hline
# Tianjing & 105.424$\pm$0.06 & 191.853$\pm$0.109 & 333.263$\pm$0.19 \\
# \hline
# Hebei & 560.605$\pm$0.365 & 1020.2$\pm$0.664 & 1772.162$\pm$1.154 \\
# \hline
# Shanxi & 361.995$\pm$0.226 & 658.765$\pm$0.411 & 1144.324$\pm$0.715 \\
# \hline
# Inner Mongolia & 210.321$\pm$0.084 & 382.746$\pm$0.152 & 664.857$\pm$0.264 \\
# \hline
# Liaoning & 307.972$\pm$0.023 & 560.454$\pm$0.043 & 973.55$\pm$0.074 \\
# \hline
# Jilin & 150.551$\pm$0.05 & 273.976$\pm$0.092 & 475.916$\pm$0.159 \\
# \hline
# Heilongjiang & 275.089$\pm$0.111 & 500.613$\pm$0.202 & 869.602$\pm$0.35 \\
# \hline
# Shanghai & 238.568$\pm$0.112 & 434.15$\pm$0.203 & 754.151$\pm$0.353 \\
# \hline
# Jiangsu & 736.595$\pm$0.124 & 1340.47$\pm$0.225 & 2328.494$\pm$0.391 \\
# \hline
# Zhejiang & 655.93$\pm$0.498 & 1193.674$\pm$0.905 & 2073.499$\pm$1.573 \\
# \hline
# Anhui & 441.965$\pm$0.279 & 804.296$\pm$0.507 & 1397.121$\pm$0.881 \\
# \hline
# Fujian & 476.907$\pm$0.116 & 867.885$\pm$0.211 & 1507.58$\pm$0.366 \\
# \hline
# Jiangxi & 463.797$\pm$0.076 & 844.027$\pm$0.138 & 1466.137$\pm$0.239 \\
# \hline
# Shandong & 723.31$\pm$0.486 & 1316.294$\pm$0.885 & 2286.5$\pm$1.537 \\
# \hline
# Henan & 492.433$\pm$0.821 & 896.14$\pm$1.493 & 1556.661$\pm$2.594 \\
# \hline
# Hubei & 490.358$\pm$0.158 & 892.362$\pm$0.288 & 1550.099$\pm$0.501 \\
# \hline
# Hunan & 448.75$\pm$0.19 & 816.643$\pm$0.345 & 1418.57$\pm$0.6 \\
# \hline
# Guangdong & 959.886$\pm$0.966 & 1746.819$\pm$1.758 & 3034.353$\pm$3.053 \\
# \hline
# Guangxi & 340.776$\pm$0.108 & 620.151$\pm$0.197 & 1077.248$\pm$0.342 \\
# \hline
# Hainan & 87.102$\pm$0.227 & 158.51$\pm$0.414 & 275.343$\pm$0.719 \\
# \hline
# Chongqing & 335.85$\pm$0.179 & 611.187$\pm$0.326 & 1061.677$\pm$0.566 \\
# \hline
# Sichuan & 649.776$\pm$0.555 & 1182.475$\pm$1.011 & 2054.047$\pm$1.756 \\
# \hline
# Guizhou & 459.834$\pm$0.211 & 836.816$\pm$0.383 & 1453.611$\pm$0.666 \\
# \hline
# Yunnan & 599.825$\pm$0.41 & 1091.573$\pm$0.747 & 1896.142$\pm$1.297 \\
# \hline
# Tibet & 67.833$\pm$0.29 & 123.443$\pm$0.527 & 214.43$\pm$0.916 \\
# \hline
# Shaanxi & 337.559$\pm$0.194 & 614.296$\pm$0.353 & 1067.078$\pm$0.613 \\
# \hline
# Gansu & 202.241$\pm$0.017 & 368.042$\pm$0.031 & 639.316$\pm$0.053 \\
# \hline
# Qinghai & 57.204$\pm$0.112 & 104.1$\pm$0.204 & 180.83$\pm$0.354 \\
# \hline
# Ningxia & 70.916$\pm$0.131 & 129.053$\pm$0.239 & 224.175$\pm$0.415 \\
# \hline
# Xinjiang & 207.82$\pm$0.084 & 378.196$\pm$0.153 & 656.954$\pm$0.265 \\
# \hline
# All over China & 11683.678$\pm$7.406 & 21262.189$\pm$13.478 & 36933.99$\pm$23.412 \\

# %%
for year in ['2022']:
    print(year, '\n\n\n')
    ER = {'Threshold-Based Method':0, 'Heuristic-Based Method':0, 'RL-Based Method':0}
    ER_std = {'Threshold-Based Method':0, 'Heuristic-Based Method':0, 'RL-Based Method':0}
    for p in Province_list:
        ER[Method_list[0]] += Energy_Reduction[year][Method_list[0]][p]
        ER[Method_list[1]] += Energy_Reduction[year][Method_list[1]][p]
        ER[Method_list[2]] += Energy_Reduction[year][Method_list[2]][p]
        ER_std[Method_list[0]] += Energy_Reduction_std[year][Method_list[0]][p]
        ER_std[Method_list[1]] += Energy_Reduction_std[year][Method_list[1]][p]
        ER_std[Method_list[2]] += Energy_Reduction_std[year][Method_list[2]][p]
        print('\hline')
        print(f'{p} & {round(Energy_Reduction[year][Method_list[0]][p]/1000, 3)}$\pm${round(Energy_Reduction_std[year][Method_list[0]][p]/1000, 3)} & {round(Energy_Reduction[year][Method_list[1]][p]/1000, 3)}$\pm${round(Energy_Reduction_std[year][Method_list[1]][p]/1000, 3)} & {round(Energy_Reduction[year][Method_list[2]][p]/1000, 3)}$\pm${round(Energy_Reduction_std[year][Method_list[2]][p]/1000, 3)} \\\\')
    print('\hline')
    print(f'All over China & {round(ER[Method_list[0]]/1000, 3)}$\pm${round(ER_std[Method_list[0]]/1000, 3)} & {round(ER[Method_list[1]]/1000, 3)}$\pm${round(ER_std[Method_list[1]]/1000, 3)} & {round(ER[Method_list[2]]/1000, 3)}$\pm${round(ER_std[Method_list[2]]/1000, 3)} \\\\')
# Out:
# 2022
#
#
#
# \hline
# Beijing & 162.447$\pm$0.284 & 295.624$\pm$0.517 & 513.52$\pm$0.898 \\
# \hline
# Tianjing & 103.41$\pm$0.013 & 188.187$\pm$0.023 & 326.894$\pm$0.041 \\
# \hline
# Hebei & 549.927$\pm$0.718 & 1000.769$\pm$1.307 & 1738.409$\pm$2.27 \\
# \hline
# Shanxi & 356.517$\pm$0.039 & 648.797$\pm$0.071 & 1127.008$\pm$0.123 \\
# \hline
# Inner Mongolia & 206.52$\pm$0.049 & 375.829$\pm$0.089 & 652.843$\pm$0.154 \\
# \hline
# Liaoning & 301.364$\pm$0.206 & 548.428$\pm$0.375 & 952.66$\pm$0.651 \\
# \hline
# Jilin & 146.831$\pm$0.182 & 267.206$\pm$0.331 & 464.157$\pm$0.575 \\
# \hline
# Heilongjiang & 270.672$\pm$0.039 & 492.574$\pm$0.07 & 855.638$\pm$0.122 \\
# \hline
# Shanghai & 234.893$\pm$0.238 & 427.463$\pm$0.433 & 742.535$\pm$0.752 \\
# \hline
# Jiangsu & 723.704$\pm$0.547 & 1317.01$\pm$0.995 & 2287.744$\pm$1.729 \\
# \hline
# Zhejiang & 644.334$\pm$0.876 & 1172.572$\pm$1.593 & 2036.844$\pm$2.768 \\
# \hline
# Anhui & 433.7$\pm$0.548 & 789.256$\pm$0.996 & 1370.995$\pm$1.731 \\
# \hline
# Fujian & 470.454$\pm$0.333 & 856.142$\pm$0.605 & 1487.181$\pm$1.051 \\
# \hline
# Jiangxi & 458.545$\pm$0.099 & 834.47$\pm$0.18 & 1449.536$\pm$0.312 \\
# \hline
# Shandong & 707.726$\pm$0.991 & 1287.933$\pm$1.804 & 2237.235$\pm$3.134 \\
# \hline
# Henan & 478.143$\pm$1.292 & 870.134$\pm$2.351 & 1511.488$\pm$4.084 \\
# \hline
# Hubei & 482.82$\pm$0.409 & 878.646$\pm$0.744 & 1526.273$\pm$1.292 \\
# \hline
# Hunan & 440.03$\pm$0.49 & 800.775$\pm$0.891 & 1391.005$\pm$1.548 \\
# \hline
# Guangdong & 938.543$\pm$1.646 & 1707.979$\pm$2.995 & 2966.885$\pm$5.203 \\
# \hline
# Guangxi & 332.12$\pm$0.405 & 604.398$\pm$0.737 & 1049.884$\pm$1.28 \\
# \hline
# Hainan & 85.724$\pm$0.173 & 156.002$\pm$0.315 & 270.987$\pm$0.548 \\
# \hline
# Chongqing & 330.396$\pm$0.008 & 601.261$\pm$0.015 & 1044.435$\pm$0.026 \\
# \hline
# Sichuan & 635.198$\pm$1.038 & 1155.947$\pm$1.889 & 2007.965$\pm$3.281 \\
# \hline
# Guizhou & 454.111$\pm$0.019 & 826.4$\pm$0.034 & 1435.517$\pm$0.059 \\
# \hline
# Yunnan & 593.592$\pm$0.201 & 1080.23$\pm$0.365 & 1876.439$\pm$0.635 \\
# \hline
# Tibet & 67.369$\pm$0.27 & 122.6$\pm$0.492 & 212.966$\pm$0.855 \\
# \hline
# Shaanxi & 331.606$\pm$0.392 & 603.463$\pm$0.713 & 1048.259$\pm$1.238 \\
# \hline
# Gansu & 198.274$\pm$0.123 & 360.823$\pm$0.225 & 626.776$\pm$0.39 \\
# \hline
# Qinghai & 56.228$\pm$0.073 & 102.325$\pm$0.132 & 177.746$\pm$0.23 \\
# \hline
# Ningxia & 69.744$\pm$0.086 & 126.922$\pm$0.157 & 220.473$\pm$0.273 \\
# \hline
# Xinjiang & 203.432$\pm$0.07 & 370.21$\pm$0.127 & 643.081$\pm$0.221 \\
# \hline
# All over China & 11468.373$\pm$11.854 & 20870.372$\pm$21.573 & 36253.375$\pm$37.473 \\

# %%
for year in ['2023']:
    print(year, '\n\n\n')
    ER = {'Threshold-Based Method':0, 'Heuristic-Based Method':0, 'RL-Based Method':0}
    ER_std = {'Threshold-Based Method':0, 'Heuristic-Based Method':0, 'RL-Based Method':0}
    for p in Province_list:
        ER[Method_list[0]] += Energy_Reduction[year][Method_list[0]][p]
        ER[Method_list[1]] += Energy_Reduction[year][Method_list[1]][p]
        ER[Method_list[2]] += Energy_Reduction[year][Method_list[2]][p]
        ER_std[Method_list[0]] += Energy_Reduction_std[year][Method_list[0]][p]
        ER_std[Method_list[1]] += Energy_Reduction_std[year][Method_list[1]][p]
        ER_std[Method_list[2]] += Energy_Reduction_std[year][Method_list[2]][p]
        print('\hline')
        print(f'{p} & {round(Energy_Reduction[year][Method_list[0]][p]/1000, 3)}$\pm${round(Energy_Reduction_std[year][Method_list[0]][p]/1000, 3)} & {round(Energy_Reduction[year][Method_list[1]][p]/1000, 3)}$\pm${round(Energy_Reduction_std[year][Method_list[1]][p]/1000, 3)} & {round(Energy_Reduction[year][Method_list[2]][p]/1000, 3)}$\pm${round(Energy_Reduction_std[year][Method_list[2]][p]/1000, 3)} \\\\')
    print('\hline')
    print(f'All over China & {round(ER[Method_list[0]]/1000, 3)}$\pm${round(ER_std[Method_list[0]]/1000, 3)} & {round(ER[Method_list[1]]/1000, 3)}$\pm${round(ER_std[Method_list[1]]/1000, 3)} & {round(ER[Method_list[2]]/1000, 3)}$\pm${round(ER_std[Method_list[2]]/1000, 3)} \\\\')
# Out:
# 2023
#
#
#
# \hline
# Beijing & 129.268$\pm$1.431 & 235.244$\pm$2.604 & 408.636$\pm$4.523 \\
# \hline
# Tianjing & 86.058$\pm$0.64 & 156.61$\pm$1.166 & 272.043$\pm$2.025 \\
# \hline
# Hebei & 464.268$\pm$3.551 & 844.884$\pm$6.461 & 1467.626$\pm$11.224 \\
# \hline
# Shanxi & 311.525$\pm$1.499 & 566.919$\pm$2.728 & 984.78$\pm$4.738 \\
# \hline
# Inner Mongolia & 175.789$\pm$1.118 & 319.904$\pm$2.035 & 555.698$\pm$3.535 \\
# \hline
# Liaoning & 246.158$\pm$2.123 & 447.963$\pm$3.863 & 778.144$\pm$6.711 \\
# \hline
# Jilin & 116.581$\pm$1.252 & 212.157$\pm$2.278 & 368.532$\pm$3.957 \\
# \hline
# Heilongjiang & 233.677$\pm$1.289 & 425.251$\pm$2.346 & 738.692$\pm$4.076 \\
# \hline
# Shanghai & 200.257$\pm$1.429 & 364.431$\pm$2.6 & 633.044$\pm$4.517 \\
# \hline
# Jiangsu & 620.653$\pm$3.929 & 1129.476$\pm$7.149 & 1961.984$\pm$12.419 \\
# \hline
# Zhejiang & 551.055$\pm$3.917 & 1002.82$\pm$7.128 & 1741.973$\pm$12.381 \\
# \hline
# Anhui & 364.487$\pm$2.8 & 663.301$\pm$5.095 & 1152.203$\pm$8.85 \\
# \hline
# Fujian & 414.919$\pm$2.198 & 755.078$\pm$4.001 & 1311.626$\pm$6.95 \\
# \hline
# Jiangxi & 420.275$\pm$1.369 & 764.825$\pm$2.491 & 1328.557$\pm$4.326 \\
# \hline
# Shandong & 585.506$\pm$4.953 & 1065.516$\pm$9.014 & 1850.879$\pm$15.658 \\
# \hline
# Henan & 358.88$\pm$5.225 & 653.097$\pm$9.509 & 1134.477$\pm$16.519 \\
# \hline
# Hubei & 421.311$\pm$2.451 & 766.709$\pm$4.461 & 1331.831$\pm$7.749 \\
# \hline
# Hunan & 364.382$\pm$3.091 & 663.11$\pm$5.625 & 1151.872$\pm$9.77 \\
# \hline
# Guangdong & 777.563$\pm$6.776 & 1415.025$\pm$12.331 & 2458.003$\pm$21.419 \\
# \hline
# Guangxi & 262.143$\pm$2.803 & 477.054$\pm$5.1 & 828.677$\pm$8.86 \\
# \hline
# Hainan & 74.675$\pm$0.259 & 135.894$\pm$0.471 & 236.058$\pm$0.819 \\
# \hline
# Chongqing & 287.116$\pm$1.493 & 522.499$\pm$2.717 & 907.619$\pm$4.72 \\
# \hline
# Sichuan & 516.132$\pm$4.978 & 939.267$\pm$9.059 & 1631.576$\pm$15.736 \\
# \hline
# Guizhou & 410.57$\pm$1.441 & 747.164$\pm$2.622 & 1297.879$\pm$4.554 \\
# \hline
# Yunnan & 539.832$\pm$1.607 & 982.396$\pm$2.924 & 1706.495$\pm$5.079 \\
# \hline
# Tibet & 63.909$\pm$0.127 & 116.302$\pm$0.23 & 202.026$\pm$0.4 \\
# \hline
# Shaanxi & 284.459$\pm$1.957 & 517.664$\pm$3.561 & 899.221$\pm$6.187 \\
# \hline
# Gansu & 164.342$\pm$1.324 & 299.072$\pm$2.409 & 519.51$\pm$4.185 \\
# \hline
# Qinghai & 48.65$\pm$0.234 & 88.535$\pm$0.425 & 153.791$\pm$0.738 \\
# \hline
# Ningxia & 60.946$\pm$0.25 & 110.911$\pm$0.456 & 192.661$\pm$0.792 \\
# \hline
# Xinjiang & 167.784$\pm$1.319 & 305.336$\pm$2.401 & 530.391$\pm$4.17 \\
# \hline
# All over China & 9723.169$\pm$68.831 & 17694.415$\pm$125.26 & 30736.503$\pm$217.586 \\
